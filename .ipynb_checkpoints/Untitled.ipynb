# %%
# !pip install sympy
# Out:
# ...
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#      ---------------------------------------- 0.1/5.7 MB 825.8 kB/s eta 0:00:07
#       --------------------------------------- 0.1/5.7 MB 939.4 kB/s eta 0:00:06
#      - -------------------------------------- 0.2/5.7 MB 1.4 MB/s eta 0:00:04
#      -- ------------------------------------- 0.3/5.7 MB 1.6 MB/s eta 0:00:04
#      --- ------------------------------------ 0.4/5.7 MB 1.7 MB/s eta 0:00:04
#      --- ------------------------------------ 0.5/5.7 MB 1.8 MB/s eta 0:00:03
#      --- ------------------------------------ 0.6/5.7 MB 1.8 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.6/5.7 MB 1.6 MB/s eta 0:00:04
#      ----- ---------------------------------- 0.7/5.7 MB 1.7 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.7/5.7 MB 1.7 MB/s eta 0:00:03
# ...

# %%
import sympy as sp

# %%
j,w = sp.symbols('j,w')

# %%
j = w**2
j
# Out:
# w**2

# %%
df = sp.diff(j,w)
df
# Out:
# 2*w

# %%
df.subs([(w,2)])
# Out:
# 4
